# %%
# Package imports

# Basics
import numpy as np
import pandas as pd

# Visualization
from plotnine import *
import matplotlib.pyplot as plt

# Fixed Effects
import linearmodels as lm
import statsmodels.formula.api as smf
#from statsmodels.regression.linear_model import OLS

# General ML
import sklearn
from sklearn.pipeline import Pipeline

# Splits and CV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV 

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Machine learning regression algorithms 
from sklearn.linear_model import LinearRegression as LR
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor as RF

# Model Interpretation
from sklearn.inspection import partial_dependence
from sklearn.inspection import plot_partial_dependence
from sklearn.inspection import permutation_importance
from pdpbox import pdp

# %%
# Data import
df = pd.read_csv("../Data/GeneratedData/Cleaned_Data_Restricted.csv", index_col = "Unnamed: 0")
df.sample(5)
# Out:
#          Country  Life_Satisfaction  Diag_Account    EDI  Suffrage  \
# 1692    Zimbabwe           3.703191         0.441  0.297     100.0
# 1091       Niger           4.267170         0.821  0.439     100.0
# 652        India           4.720147         0.859  0.680     100.0
# 764   Kazakhstan           5.886420         0.456  0.251     100.0
# 786        Kenya           4.475654         0.805  0.467     100.0
#
#              GDPpc   Ineq_Frac
# 1692   1560.000000   36.120936
# 1091    775.253443  697.387433
# 652    4932.000000   97.705538
# 764   18665.765332    7.850014
# 786    3249.877118   29.887165

# %%
len(df)
# Out:
# 1546

# %%
df.isnull().any(axis=1).sum()
# Out:
# 0

# %%
# Data import 2
df_full = pd.read_csv("../Data/GeneratedData/Cleaned_Data_Full.csv", index_col = "Unnamed: 0")
df_full.sample(5)
# Out:
#            Country  Life_Satisfaction    EDI  Suffrage  Diag_Account    AFI  \
# 1358  South Africa           4.652429  0.753     100.0         0.946  0.768
# 1409     Sri Lanka           4.180569  0.463     100.0         0.529  0.352
# 279           Chad           4.393482  0.275     100.0         0.549    NaN
# 848        Liberia           4.196063  0.653     100.0         0.943  0.779
# 1215      Portugal           5.126912  0.868     100.0         0.948  0.967
#
#       Democracy         GDPpc  Avg_Hours_Worked  U_Coverage   Ineq_Frac  \
# 1358        1.0  11318.604549           44.3325        30.1   20.142587
# 1409        0.0   8918.000000           46.1582         NaN   16.513093
# 279         0.0   1661.000000               NaN         NaN  273.471168
# 848         1.0    854.234973               NaN         NaN  406.864091
# 1215        1.0  24423.000000               NaN        17.1    6.212048
#
#       Min_Wage  Gender_Pay_Gap  Mean_Earnings  Percent_Low_Income_Female
# 1358    284.65             NaN            NaN                      49.83
# 1409       NaN             NaN         137.73                        NaN
# 279     127.32             NaN            NaN                        NaN
# 848        NaN             NaN           4.66                        NaN
# 1215    751.71           14.85            NaN                      56.20

# %%
len(df_full)
# Out:
# 1696

# %%
df_full.isnull().any(axis=1).sum()
# Out:
# 1690

# %%
# Data import 3
df_I = pd.read_csv("../Data/GeneratedData/Cleaned_Data_Imputed.csv", index_col = "Unnamed: 0")
df_I.sample(5)
# Out:
#       Country  Life_Satisfaction    EDI  Suffrage  Diag_Account    AFI  \
# 1566  Ukraine           4.710803  0.451     100.0         0.794  0.727
# 743     Japan           5.959362  0.833     100.0         0.911  0.748
# 793    Kuwait           6.480031  0.310     100.0         0.625  0.483
# 1446    Syria           4.978971  0.150     100.0         0.088  0.097
# 1050    Nepal           4.910087  0.640     100.0         0.838  0.712
#
#              GDPpc  Avg_Hours_Worked  U_Coverage  Ineq_Frac     Min_Wage  \
# 1566  10404.000000         53.152892   13.366328   7.589133   152.380000
# 743   36354.000000         34.546778   17.700000  12.845031  1356.890000
# 793   75256.000000         -5.884021    5.691644  11.591458   849.986716
# 1446   6586.518348         54.135272   18.684727  21.606359   544.320000
# 1050   2727.423815         64.644100   24.782350   2.642749   866.449141
#
#       Gender_Pay_Gap  Mean_Earnings  Percent_Low_Income_Female
# 1566      -61.502706     408.480000                  21.574545
# 743        23.985668    3029.850000                  63.323823
# 793       250.319357    8070.743217                 125.737297
# 1446     -102.442454     988.510000                  15.322520
# 1050     -111.771569   -1816.018017                   9.419628

# %%
len(df_I)
# Out:
# 1696

# %%
# Data import 3
df_U = pd.read_csv("../Data/GeneratedData/Cleaned_Data_Union.csv", index_col = "Unnamed: 0")
df_U.sample(5)
# Out:
#              Country  Life_Satisfaction  Diag_Account    EDI  Suffrage  \
# 1453          Taiwan           5.547682         0.926  0.758     100.0
# 1191     Philippines           5.001965         0.924  0.582     100.0
# 1375     South Korea           5.767276         0.931  0.859     100.0
# 1431          Sweden           7.434011         0.962  0.912     100.0
# 1586  United Kingdom           6.906547         0.951  0.867     100.0
#
#              GDPpc  U_Coverage  Ineq_Frac
# 1453  34762.367306        38.5  13.604927
# 1191   6144.000000         8.5  19.939938
# 1375  29716.570420        10.6  15.434059
# 1431  41811.000000        67.7   6.720732
# 1586  34402.357979        27.4   9.730034

# %%
len(df_U)
# Out:
# 572

# %% [markdown]
# # Methods
# In this notebook, I will set up a machine learning pipeline, run various models, assess their results, and interpret these results.

# %% [markdown]
# ## Logging Variables
# Before we get started, we're going to log both `GDPpc_2011_prices` and `Inequality_Frac`.

# %%
# Logs GDP per capita
df['GDPpc'] =  np.where(df['GDPpc']==0,0,np.log(df['GDPpc']))
df_full['GDPpc'] =  np.where(df_full['GDPpc']==0,0,np.log(df_full['GDPpc']))

# %%
# Logs GDP per capita
df['Ineq_Frac'] =  np.where(df['Ineq_Frac']==0,0,np.log(df['Ineq_Frac']))
df_full['Ineq_Frac'] =  np.where(df_full['Ineq_Frac']==0,0,np.log(df_full['Ineq_Frac']))

# %% [markdown]
# ## Models

# %% [markdown]
# ## Restricted Fixed Effects
# The following analysis does NOT use the union membership and average work hours variables

# %%
FE_ols = smf.ols(formula='Life_Satisfaction ~ 1 + Diag_Account + EDI + Suffrage + GDPpc + Ineq_Frac + C(Country)', data = df).fit()
#print(FE_ols.summary())

# %%
# Converts the results to a dataframe
results = FE_ols.summary()
results_as_html = results.tables[1].as_html()
results = pd.read_html(results_as_html, header=0, index_col=0)[0].reset_index()

# %%
results.tail(10)
# Out:
#                        index    coef  std err      t  P>|t|  [0.025  0.975]
# 151  C(Country)[T.Venezuela]  0.1522    0.369  0.412  0.680  -0.572   0.876
# 152    C(Country)[T.Vietnam]  0.2029    0.286  0.710  0.478  -0.357   0.763
# 153      C(Country)[T.Yemen] -0.7577    0.236 -3.212  0.001  -1.220  -0.295
# 154     C(Country)[T.Zambia]  0.3770    0.173  2.183  0.029   0.038   0.716
# 155   C(Country)[T.Zimbabwe] -0.1149    0.246 -0.468  0.640  -0.597   0.367
# 156             Diag_Account -0.0049    0.232 -0.021  0.983  -0.459   0.449
# 157                      EDI  0.2416    0.250  0.968  0.333  -0.248   0.731
# 158                 Suffrage -0.0080    0.013 -0.617  0.537  -0.033   0.017
# 159                    GDPpc  0.6199    0.087  7.104  0.000   0.449   0.791
# 160                Ineq_Frac -0.2672    0.092 -2.907  0.004  -0.447  -0.087

# %% [markdown]
# ## Full Fixed Effects
# The following analysis uses the union membership and average work hours variables

# %%
FE_ols_full = smf.ols(formula='Life_Satisfaction ~ 1 + Diag_Account + EDI + Suffrage + GDPpc + Ineq_Frac + Min_Wage + U_Coverage + C(Country)', data = df_full).fit()
#print(FE_ols.summary())

# %%
# Converts the results to a dataframe
results_full = FE_ols_full.summary()
results_as_html = results_full.tables[1].as_html()
results_full = pd.read_html(results_as_html, header=0, index_col=0)[0].reset_index()

# %%
results_full.tail(10)
# Out:
#                       index      coef  std err      t  P>|t|  [0.025  0.975]
# 158     C(Country)[T.Yemen]  0.000000    0.000    NaN    NaN   0.000   0.000
# 159    C(Country)[T.Zambia]  0.000000    0.000    NaN    NaN   0.000   0.000
# 160  C(Country)[T.Zimbabwe]  0.000000    0.000    NaN    NaN   0.000   0.000
# 161            Diag_Account -0.414700    0.722 -0.574  0.566  -1.836   1.007
# 162                     EDI  1.076800    0.799  1.347  0.179  -0.496   2.650
# 163                Suffrage  0.270400    0.183  1.480  0.140  -0.089   0.630
# 164                   GDPpc  1.431500    0.255  5.605  0.000   0.929   1.934
# 165               Ineq_Frac  0.111100    0.187  0.593  0.554  -0.258   0.480
# 166                Min_Wage -0.000012    0.000 -0.084  0.933  -0.000   0.000
# 167              U_Coverage  0.004200    0.008  0.550  0.582  -0.011   0.019

# %% [markdown]
# ## Imputed Fixed Effects
# The following analysis uses the union membership and average work hours variables

# %%
FE_ols_I = smf.ols(formula='Life_Satisfaction ~ 1 + Diag_Account + EDI + Suffrage + GDPpc + Ineq_Frac + Min_Wage + U_Coverage + C(Country)', data = df_I).fit()
#print(FE_ols.summary())

# %%
# Converts the results to a dataframe
results_I = FE_ols_I.summary()
results_as_html = results_I.tables[1].as_html()
results_I = pd.read_html(results_as_html, header=0, index_col=0)[0].reset_index()

# %%
results_I.tail(10)
# Out:
#                       index      coef   std err      t  P>|t|    [0.025  \
# 157   C(Country)[T.Vietnam]  1.247600  0.184000  6.781  0.000  0.887000
# 158     C(Country)[T.Yemen] -0.104700  0.183000 -0.572  0.567 -0.463000
# 159    C(Country)[T.Zambia]  0.734900  0.165000  4.457  0.000  0.412000
# 160  C(Country)[T.Zimbabwe]  0.077200  0.178000  0.434  0.665 -0.272000
# 161            Diag_Account -0.222200  0.217000 -1.022  0.307 -0.649000
# 162                     EDI  0.520800  0.244000  2.133  0.033  0.042000
# 163                Suffrage -0.003900  0.003000 -1.358  0.175 -0.009000
# 164                   GDPpc  0.000022  0.000005  4.870  0.000  0.000013
# 165               Ineq_Frac -0.001200  0.000000 -3.413  0.001 -0.002000
# 166              U_Coverage -0.001500  0.002000 -0.998  0.319 -0.005000
#
#        0.975]
# 157  1.608000
# 158  0.254000
# 159  1.058000
# 160  0.426000
# 161  0.204000
# 162  1.000000
# 163  0.002000
# 164  0.000031
# 165 -0.001000
# 166  0.001000

# %%
len(results_I)
# Out:
# 167

# %% [markdown]
# ## Union Fixed Effects
# The following analysis uses the union membership and average work hours variables

# %%
FE_ols_U = smf.ols(formula='Life_Satisfaction ~ 1 + Diag_Account + EDI + Suffrage + GDPpc + Ineq_Frac + U_Coverage + C(Country)', data = df_U).fit()
#print(FE_ols.summary())

# %%
# Converts the results to a dataframe
results_U = FE_ols_U.summary()
results_as_html = results_U.tables[1].as_html()
results_U = pd.read_html(results_as_html, header=0, index_col=0)[0].reset_index()

# %%
results_U.tail(10)
# Out:
#                       index     coef   std err      t  P>|t|    [0.025  \
# 90  C(Country)[T.Venezuela]  1.10890  0.286000  3.871  0.000  0.546000
# 91    C(Country)[T.Vietnam]  0.51360  0.388000  1.323  0.187 -0.249000
# 92     C(Country)[T.Zambia] -0.14840  0.743000 -0.200  0.842 -1.609000
# 93   C(Country)[T.Zimbabwe] -0.25490  0.388000 -0.658  0.511 -1.017000
# 94             Diag_Account -0.73750  0.621000 -1.187  0.236 -1.958000
# 95                      EDI  0.85840  0.686000  1.250  0.212 -0.491000
# 96                 Suffrage  0.40240  0.185000  2.172  0.030  0.038000
# 97                    GDPpc  0.00004  0.000008  5.065  0.000  0.000024
# 98                Ineq_Frac -0.00310  0.006000 -0.556  0.578 -0.014000
# 99               U_Coverage  0.00710  0.006000  1.174  0.241 -0.005000
#
#       0.975]
# 90  1.672000
# 91  1.277000
# 92  1.312000
# 93  0.507000
# 94  0.483000
# 95  2.207000
# 96  0.766000
# 97  0.000055
# 98  0.008000
# 99  0.019000

# %%
len(results_U)
# Out:
# 100
