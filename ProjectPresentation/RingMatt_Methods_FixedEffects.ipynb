# %%
# Package imports

# Basics
import numpy as np
import pandas as pd

# Visualization
from plotnine import *
import matplotlib.pyplot as plt

# Fixed Effects
import linearmodels as lm
import statsmodels.formula.api as smf
#from statsmodels.regression.linear_model import OLS

# General ML
import sklearn
from sklearn.pipeline import Pipeline

# Splits and CV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV 

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Machine learning regression algorithms 
from sklearn.linear_model import LinearRegression as LR
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor as RF

# Model Interpretation
from sklearn.inspection import partial_dependence
from sklearn.inspection import plot_partial_dependence
from sklearn.inspection import permutation_importance
from pdpbox import pdp

# %%
# Data import
df = pd.read_csv("Data/GeneratedData/Cleaned_Data_Restricted.csv", index_col = "Unnamed: 0")
df.sample(5)
# Out:
#              Country  Life_Satisfaction  Diag_Account    EDI  Suffrage  \
# 41         Argentina           6.671114         0.907  0.764    100.00
# 1497        Thailand           6.201763         0.281  0.150     99.23
# 736            Japan           6.515817         0.927  0.857    100.00
# 1587  United Kingdom           7.029364         0.949  0.869    100.00
# 742            Japan           5.968216         0.928  0.858    100.00
#
#              GDPpc  Ineq_Frac    AFI
# 41    19183.000000   9.509527  0.888
# 1497  15020.000000  18.639030  0.192
# 736   34857.755820  13.246765  0.748
# 1587  34754.472261  10.293201  0.920
# 742   35580.000000  12.879483  0.748

# %%
len(df)
# Out:
# 1240

# %%
# Data import 2
df_full = pd.read_csv("Data/GeneratedData/Cleaned_Data_Full.csv", index_col = "Unnamed: 0")
df_full.sample(5)
# Out:
#                      Country  Year  Life_Satisfaction    EDI  Suffrage  \
# 174   Bosnia and Herzegovina  2014           5.248954  0.580     100.0
# 411                  Denmark  2015           7.514425  0.902     100.0
# 1245                  Russia  2014           6.036977  0.295     100.0
# 908                   Malawi  2013           4.035084  0.599     100.0
# 1222                   Qatar  2011           6.591604  0.084     100.0
#
#       Diag_Account    AFI  Democracy     GDPpc  Avg_Hours_Worked  U_Coverage  \
# 174          0.879  0.719        1.0    9201.0           42.3732         NaN
# 411          0.976  0.940        1.0   44635.0               NaN        68.6
# 1245         0.409  0.430        0.0   24387.0           38.8897        31.2
# 908          0.875  0.726        1.0    1104.0           34.1332         5.5
# 1222         0.220    NaN        0.0  155533.0               NaN         NaN
#
#       Ineq_Diff  Ineq_Frac
# 174   16.780696  11.598294
# 411    9.658316   5.382833
# 1245  15.100248   6.547498
# 908   59.180354  37.387067
# 1222  26.834926  11.067440

# %%
len(df_full)
# Out:
# 1696

# %%
# Data import 3
df_I = pd.read_csv("Data/GeneratedData/Cleaned_Data_Imputed.csv", index_col = "Unnamed: 0")
df_I.sample(5)
# Out:
#         Country  Life_Satisfaction    EDI  Suffrage  Diag_Account       AFI  \
# 644     Iceland           7.510035  0.858     100.0         0.940  0.848738
# 210    Bulgaria           4.837561  0.713     100.0         0.873  0.863000
# 689        Iraq           4.541502  0.438     100.0         0.682  0.552812
# 763  Kazakhstan           5.718554  0.247     100.0         0.463  0.328000
# 645     Iceland           7.476214  0.890     100.0         0.948  0.917756
#
#             GDPpc  Avg_Hours_Worked  U_Coverage  Ineq_Frac
# 644  42085.000000         36.228011   90.400000   6.846441
# 210  17037.000000         41.415136   13.700000   5.471968
# 689  12817.000000         42.049323   16.608328  16.364711
# 763  18181.059822         41.226567   20.735813   7.927540
# 645  42978.234912         38.687921   26.528031   6.840148

# %%
len(df_I)
# Out:
# 1696

# %% [markdown]
# # Methods
# In this notebook, I will set up a machine learning pipeline, run various models, assess their results, and interpret these results.

# %% [markdown]
# ## Logging Variables
# Before we get started, we're going to log both `GDPpc_2011_prices` and `Inequality_Frac`.

# %%
# Logs GDP per capita
df['GDPpc'] =  np.where(df['GDPpc']==0,0,np.log(df['GDPpc']))
df_full['GDPpc'] =  np.where(df_full['GDPpc']==0,0,np.log(df_full['GDPpc']))

# %%
# Logs GDP per capita
df['Ineq_Frac'] =  np.where(df['Ineq_Frac']==0,0,np.log(df['Ineq_Frac']))
df_full['Ineq_Frac'] =  np.where(df_full['Ineq_Frac']==0,0,np.log(df_full['Ineq_Frac']))

# %% [markdown]
# ## Models

# %% [markdown]
# ## Restricted Fixed Effects
# The following analysis does NOT use the union membership and average work hours variables

# %%
FE_ols = smf.ols(formula='Life_Satisfaction ~ 1 + Diag_Account + EDI + Suffrage + GDPpc + Ineq_Frac + AFI + C(Country)', data = df).fit()
#print(FE_ols.summary())

# %%
# Converts the results to a dataframe
results = FE_ols.summary()
results_as_html = results.tables[1].as_html()
results = pd.read_html(results_as_html, header=0, index_col=0)[0].reset_index()

# %%
results.loc[results["P>|t|"] < 0.05]
# Out:
#                        index    coef  std err      t  P>|t|  [0.025  0.975]
# 1      C(Country)[T.Algeria]  0.9878    0.222  4.443  0.000   0.552   1.424
# 2    C(Country)[T.Argentina]  0.9277    0.174  5.334  0.000   0.586   1.269
# 3      C(Country)[T.Armenia] -0.4156    0.160 -2.598  0.009  -0.729  -0.102
# 4      C(Country)[T.Austria]  1.1134    0.220  5.064  0.000   0.682   1.545
# 6      C(Country)[T.Bahrain]  0.7059    0.256  2.758  0.006   0.204   1.208
# ..                       ...     ...      ...    ...    ...     ...     ...
# 125   C(Country)[T.Zimbabwe]  1.4220    0.301  4.717  0.000   0.830   2.014
# 126             Diag_Account -0.6363    0.298 -2.137  0.033  -1.220  -0.052
# 129                    GDPpc  0.6646    0.093  7.160  0.000   0.482   0.847
# 130                Ineq_Frac -0.3155    0.096 -3.299  0.001  -0.503  -0.128
# 131                      AFI  1.2982    0.298  4.360  0.000   0.714   1.882
#
# [91 rows x 7 columns]

# %% [markdown]
# ## Full Fixed Effects
# The following analysis uses the union membership and average work hours variables

# %%
FE_ols_full = smf.ols(formula='Life_Satisfaction ~ 1 + Diag_Account + EDI + Suffrage + GDPpc + Ineq_Frac + AFI + Avg_Hours_Worked + U_Coverage + C(Country)', data = df_full).fit()
#print(FE_ols.summary())

# %%
# Converts the results to a dataframe
results_full = FE_ols_full.summary()
results_as_html = results_full.tables[1].as_html()
results_full = pd.read_html(results_as_html, header=0, index_col=0)[0].reset_index()

# %%
results_full.loc[results_full["P>|t|"] < 0.05]
# Out:
#                           index          coef       std err      t  P>|t|  \
# 14         C(Country)[T.Bhutan]  9.289000e-14  4.490000e-14  2.069  0.042
# 17       C(Country)[T.Botswana]  4.211000e-14  1.790000e-14  2.347  0.021
# 18         C(Country)[T.Brazil]  1.075400e+00  3.060000e-01  3.512  0.001
# 27          C(Country)[T.Chile]  9.102000e-01  4.140000e-01  2.200  0.031
# 29       C(Country)[T.Colombia]  8.699000e-01  3.060000e-01  2.840  0.006
# 34        C(Country)[T.Croatia] -1.097800e+00  4.270000e-01 -2.571  0.012
# 56      C(Country)[T.Guatemala]  1.204400e+00  5.460000e-01  2.205  0.030
# 57         C(Country)[T.Guinea]  1.462000e-16  6.990000e-17  2.092  0.039
# 69         C(Country)[T.Israel]  1.276900e+00  4.410000e-01  2.893  0.005
# 94         C(Country)[T.Mexico]  1.865900e+00  3.410000e-01  5.467  0.000
# 124        C(Country)[T.Serbia] -1.335300e+00  4.260000e-01 -3.137  0.002
# 130  C(Country)[T.South Africa] -1.161400e+00  3.520000e-01 -3.297  0.001
# 134     C(Country)[T.Sri Lanka] -1.636000e+00  6.690000e-01 -2.444  0.017
# 150       C(Country)[T.Ukraine] -2.199200e+00  9.370000e-01 -2.347  0.021
# 166                         AFI -2.769700e+00  1.324000e+00 -2.092  0.039
#
#            [0.025        0.975]
# 14   3.620000e-15  1.820000e-13
# 17   6.430000e-15  7.780000e-14
# 18   4.670000e-01  1.684000e+00
# 27   8.700000e-02  1.733000e+00
# 29   2.610000e-01  1.479000e+00
# 34  -1.947000e+00 -2.490000e-01
# 56   1.180000e-01  2.291000e+00
# 57   7.250000e-18  2.850000e-16
# 69   3.990000e-01  2.155000e+00
# 94   1.187000e+00  2.545000e+00
# 124 -2.182000e+00 -4.890000e-01
# 130 -1.862000e+00 -4.610000e-01
# 134 -2.967000e+00 -3.050000e-01
# 150 -4.062000e+00 -3.360000e-01
# 166 -5.403000e+00 -1.360000e-01

# %% [markdown]
# ## Imputed Fixed Effects
# The following analysis uses the union membership and average work hours variables

# %%
FE_ols_I = smf.ols(formula='Life_Satisfaction ~ 1 + Diag_Account + EDI + Suffrage + GDPpc + Ineq_Frac + AFI + Avg_Hours_Worked + U_Coverage + C(Country)', data = df_I).fit()
#print(FE_ols.summary())

# %%
# Converts the results to a dataframe
results_I = FE_ols_I.summary()
results_as_html = results_I.tables[1].as_html()
results_I = pd.read_html(results_as_html, header=0, index_col=0)[0].reset_index()

# %%
results_I.loc[results_I["P>|t|"] < 0.05]
# Out:
#                        index      coef   std err      t  P>|t|    [0.025  \
# 0                  Intercept  4.444100  0.464000  9.570  0.000  3.533000
# 1      C(Country)[T.Albania]  0.498500  0.203000  2.452  0.014  0.100000
# 2      C(Country)[T.Algeria]  1.177900  0.210000  5.620  0.000  0.767000
# 4    C(Country)[T.Argentina]  1.578900  0.221000  7.142  0.000  1.145000
# 6    C(Country)[T.Australia]  1.793400  0.301000  5.954  0.000  1.203000
# ..                       ...       ...       ...    ...    ...       ...
# 157    C(Country)[T.Vietnam]  1.091200  0.191000  5.713  0.000  0.717000
# 159     C(Country)[T.Zambia]  0.410600  0.188000  2.183  0.029  0.042000
# 161             Diag_Account -0.612900  0.241000 -2.545  0.011 -1.085000
# 164                    GDPpc  0.000024  0.000005  5.268  0.000  0.000015
# 166                      AFI  0.751700  0.209000  3.591  0.000  0.341000
#
#        0.975]
# 0    5.355000
# 1    0.897000
# 2    1.589000
# 4    2.013000
# 6    2.384000
# ..        ...
# 157  1.466000
# 159  0.780000
# 161 -0.141000
# 164  0.000033
# 166  1.162000
#
# [119 rows x 7 columns]

# %%
len(results_I)
# Out:
# 169
